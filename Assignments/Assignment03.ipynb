# %% [markdown]
# # Reading CSV File

# %%
import pandas as pd
df = pd.read_csv('datasets_19256_25044_AAPL.csv')
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1    2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2    2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4    2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..          ...         ...         ...         ...         ...         ...
# 179  2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180  2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181  2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182  2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183  2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume
# 0    142718700
# 1    280258200
# ...

# %%
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1  2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2  2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3  2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4  2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# 5  2014-11-03  108.220001  110.300003  107.720001  109.010002  102.328766
# 6  2014-11-10  109.019997  114.190002  108.400002  114.180000  107.646675
# 7  2014-11-17  114.269997  117.570000  113.300003  116.470001  109.805626
# 8  2014-11-24  116.849998  119.750000  116.620003  118.930000  112.124863
# 9  2014-12-01  118.809998  119.250000  111.269997  115.000000  108.419746
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600
# 5  199952900
# 6  205166700
# 7  233414700
# 8  181873900
# ...

# %%
df.tail(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 174  2018-01-29  170.160004  170.160004  160.100006  160.500000  159.848282
# 175  2018-02-05  159.100006  163.880005  150.240005  156.410004  155.774887
# 176  2018-02-12  158.500000  174.820007  157.509995  172.429993  172.429993
# 177  2018-02-19  172.050003  175.649994  171.009995  175.500000  175.500000
# 178  2018-02-26  176.350006  180.619995  172.449997  176.210007  176.210007
# 179  2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180  2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181  2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182  2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183  2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume  High - Low  Open - Close
# 174  262992100   10.059998      9.660004
# 175  317654000   13.640000      2.690002
# ...

# %% [markdown]
# # Creating New Columns

# %%
df['High - Low'] = df['High'] - df['Low']
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1    2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2    2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4    2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..          ...         ...         ...         ...         ...         ...
# 179  2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180  2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181  2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182  2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183  2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume  High - Low
# 0    142718700    2.650001
# ...

# %%
df['Open - Close'] = df['Open'] - df['Close']
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1    2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2    2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4    2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..          ...         ...         ...         ...         ...         ...
# 179  2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180  2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181  2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182  2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183  2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume  High - Low  Open - Close
# ...

# %%
new_df = df.drop('Volume', axis = 1)
new_df
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1    2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2    2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4    2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..          ...         ...         ...         ...         ...         ...
# 179  2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180  2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181  2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182  2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183  2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
# [184 rows x 6 columns]

# %% [markdown]
# # Drawing different Charts based on the new columns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
new_df.head(5).plot.bar()
# Out:
# <AxesSubplot:>

# %%
new_df.tail(10).plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
new_df['Open'].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot.line(y='Volume',figsize=(12,3),lw=1)
# Out:
# <AxesSubplot:>

# %%
new_df.plot.scatter(x='High',y='Low')
# Out:
# <AxesSubplot:xlabel='High', ylabel='Low'>

# %%
new_df.plot.scatter(x='High',y='Low',c='Open',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='High', ylabel='Low'>

# %%
new_df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df['High'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
new_df.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Saving New CSV File

# %%
new_df.to_csv(r'test.csv')
